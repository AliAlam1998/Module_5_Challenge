# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
# Average tumor volume increases as weight increase for mice.
# Drug regimen Capomulin and Ramicane	have more the 200 mice involved.
# Tumor volume decreased for mouse l509 that was on Capomulin over timepoints.
# Total 249 unique Mouse IDs.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_data = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="right")
combined_data

# Display the data table for preview
combined_data.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     b128    Capomulin  Female           9          22          0
# 1     f932     Ketapril    Male          15          29          0
# 2     g107     Ketapril  Female           2          29          0
# 3     a457     Ketapril  Female          11          30          0
# 4     c819     Ketapril    Male          21          25          0
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                45.0                 0
# 1                45.0                 0
# 2                45.0                 0
# 3                45.0                 0
# 4                45.0                 0

# %%
# Checking the number of mice.
unique_mice = combined_data["Mouse ID"].nunique()
print(f"Number of unique mice IDs: {unique_mice}")
# Out:
# Number of unique mice IDs: 249

# %%
duplicate_rows = combined_data[combined_data.duplicated(subset=["Mouse ID", "Timepoint"])]
print("Duplicate mouse ID and time points:")
duplicate_rows
# Out:
# Duplicate mouse ID and time points:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 137      g989     Propriva  Female          21          26          0
# 360      g989     Propriva  Female          21          26          5
# 681      g989     Propriva  Female          21          26         10
# 869      g989     Propriva  Female          21          26         15
# 1111     g989     Propriva  Female          21          26         20
#
#       Tumor Volume (mm3)  Metastatic Sites
# 137            45.000000                 0
# 360            47.570392                 0
# 681            49.880528                 0
# 869            53.442020                 0
# 1111           54.657650                 1

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse_id = combined_data[combined_data.duplicated(subset=["Mouse ID", "Timepoint"])]['Mouse ID'].unique()
duplicate_mouse_id
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
duplicate_mouse_data = combined_data[combined_data["Mouse ID"] == 'g989']
duplicate_mouse_data
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 107      g989     Propriva  Female          21          26          0
# 137      g989     Propriva  Female          21          26          0
# 329      g989     Propriva  Female          21          26          5
# 360      g989     Propriva  Female          21          26          5
# 620      g989     Propriva  Female          21          26         10
# 681      g989     Propriva  Female          21          26         10
# 815      g989     Propriva  Female          21          26         15
# 869      g989     Propriva  Female          21          26         15
# 950      g989     Propriva  Female          21          26         20
# 1111     g989     Propriva  Female          21          26         20
# 1195     g989     Propriva  Female          21          26         25
# 1380     g989     Propriva  Female          21          26         30
# ...

# %%
filtered_data = combined_data[combined_data["Mouse ID"] != 'g989']
filtered_data.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     b128    Capomulin  Female           9          22          0
# 1     f932     Ketapril    Male          15          29          0
# 2     g107     Ketapril  Female           2          29          0
# 3     a457     Ketapril  Female          11          30          0
# 4     c819     Ketapril    Male          21          25          0
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                45.0                 0
# 1                45.0                 0
# 2                45.0                 0
# 3                45.0                 0
# 4                45.0                 0

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_data_no_duplicates = filtered_data.drop_duplicates(subset=["Mouse ID", "Timepoint"], keep=False)
cleaned_data_no_duplicates.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     b128    Capomulin  Female           9          22          0
# 1     f932     Ketapril    Male          15          29          0
# 2     g107     Ketapril  Female           2          29          0
# 3     a457     Ketapril  Female          11          30          0
# 4     c819     Ketapril    Male          21          25          0
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                45.0                 0
# 1                45.0                 0
# 2                45.0                 0
# 3                45.0                 0
# 4                45.0                 0

# %%
# Checking the number of mice in the clean DataFrame.
unique_mice_cleaned = cleaned_data_no_duplicates["Mouse ID"].nunique()
print(f"Number of unique mice IDs (after cleaning): {unique_mice_cleaned}")
# Out:
# Number of unique mice IDs (after cleaning): 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
grouped_data = cleaned_data_no_duplicates.groupby("Drug Regimen")
summary_statistics = grouped_data["Tumor Volume (mm3)"].agg(["mean", "median", "var", "std", "sem"])
summary_statistics = summary_statistics.rename(columns={
    "mean": "Mean Tumor Volume",
    "median": "Median Tumor Volume",
    "var": "Variance  Volume Variance",
    "std": "Std. Dev.",
    "sem": "Tumor Volume Std. Err."
})
print("Summary Statistics by Drug Regimen:")
summary_statistics
# Out:
# Summary Statistics by Drug Regimen:
#               Mean Tumor Volume  Median Tumor Volume  \
# Drug Regimen
# Capomulin             40.675741            41.557809
# Ceftamin              52.591172            51.776157
# Infubinol             52.884795            51.820584
# Ketapril              55.235638            53.698743
# Naftisol              54.331565            52.509285
# Placebo               54.033581            52.288934
# Propriva              52.320930            50.446266
# Ramicane              40.216745            40.673236
# Stelasyn              54.233149            52.431737
# Zoniferol             53.236507            51.818479
#
#               Variance  Volume Variance  Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                     24.947764   4.994774                0.329346
# Ceftamin                      39.290177   6.268188                0.469821
# Infubinol                     43.128684   6.567243                0.492236
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
sorted_data = grouped_data["Mouse ID"].count().sort_values(ascending=False)
bar_chart_pandas = sorted_data.plot(kind="bar", title="Total Mice per Drug Regimen (Pandas - Sorted)")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.xticks(rotation=90)
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
# Sort the grouped_data in ascending order based on the count of mice
sorted_data = grouped_data["Mouse ID"].count().sort_values(ascending=False)

# Create a bar chart with the sorted data (ascending order)
bar_chart_matplotlib = sorted_data
plt.bar(bar_chart_matplotlib.index, bar_chart_matplotlib.values)
plt.title("Total Mice per Drug Regimen (Matplotlib - Sorted)")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.xticks(rotation=90)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_distribution_pandas = cleaned_data_no_duplicates["Sex"].value_counts()
gender_distribution_pandas.plot(kind="pie", autopct="%1.1f%%", startangle=0, title="Gender Distribution (Pandas)")
plt.axis("equal")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_distribution_matplotlib = cleaned_data_no_duplicates["Sex"].value_counts()
plt.pie(gender_distribution_matplotlib, labels=gender_distribution_matplotlib.index, autopct="%1.1f%%", startangle=0)
plt.title("Gender Distribution (Matplotlib)")
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Create a list of the four specific treatment regimens
target_data = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Filter the cleaned_data DataFrame to include only the data related to the target regimens
target_data = cleaned_data_no_duplicates[cleaned_data_no_duplicates["Drug Regimen"].isin(target_regimens)]

# Group the filtered data by Mouse ID to find the last (greatest) timepoint for each mouse
final_timepoints = target_data.groupby("Mouse ID")["Timepoint"].max().reset_index()

# Merge the final_timepoints DataFrame with the original DataFrame to get the tumor volume at the last timepoint
final_tumor_volumes = pd.merge(final_timepoints, target_data, on=["Mouse ID", "Timepoint"])

# Display the DataFrame with the final tumor volumes for the selected regimens
final_tumor_volumes.head()
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     a203         45    Infubinol  Female          20          23
# 1     a251         45    Infubinol  Female          21          25
# 2     a275         45     Ceftamin  Female          20          28
# 3     a411         45     Ramicane    Male           3          22
# 4     a444         45     Ramicane  Female          10          25
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           67.973419                 2
# 1           65.525743                 1
# 2           62.999356                 3
# 3           38.407618                 1
# 4           43.047543                 0

# %%
# Group the data by Mouse ID and find the maximum timepoint for each mouse
last_timepoints = cleaned_data_no_duplicates.groupby("Mouse ID")["Timepoint"].max().reset_index()

# Merge the last_timepoints DataFrame with the original cleaned_data DataFrame
merged_data = pd.merge(last_timepoints, cleaned_data_no_duplicates, on=["Mouse ID", "Timepoint"])

# Display the DataFrame with the tumor volume at the last timepoint for each mouse
merged_data.head()
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     a203         45    Infubinol  Female          20          23
# 1     a251         45    Infubinol  Female          21          25
# 2     a262         45      Placebo  Female          17          29
# 3     a275         45     Ceftamin  Female          20          28
# 4     a366         30     Stelasyn  Female          16          29
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           67.973419                 2
# 1           65.525743                 1
# 2           70.717621                 4
# 3           62.999356                 3
# 4           63.440686                 1

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Create a list of the treatment regimens
treatment_regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
# Create an empty list to store tumor volume data for plotting
tumor_volume_data = []

# %%
# Start by getting the last (greatest) timepoint for each mouse
# Group the data by Mouse ID and find the maximum timepoint for each mouse
last_timepoints = cleaned_data_no_duplicates.groupby("Mouse ID")["Timepoint"].max().reset_index()

# Rename the "Timepoint" column to "Last Timepoint"
last_timepoints = last_timepoints.rename(columns={"Timepoint": "Last Timepoint"})

# Display the DataFrame with the last timepoint for each mouse
last_timepoints.head()
# Out:
#   Mouse ID  Last Timepoint
# 0     a203              45
# 1     a251              45
# 2     a262              45
# 3     a275              45
# 4     a366              30

# %%
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

# Create an empty list to store potential outliers
potential_outliers = []

# Loop through each treatment regimen
# Create a list of the four specific treatment regimens
target_regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Loop through each treatment regimen
for regimen in target_regimens:
# Filter the merged_data DataFrame for the current regimen
    regimen_data =merged_data[merged_data["Drug Regimen"] == regimen]["Tumor Volume (mm3)"]
    
    # Calculate quartiles and IQR
    quartiles = regimen_data.quantile([0.25, 0.75])
    lower_quartile = quartiles[0.25]
    upper_quartile = quartiles[0.75]
    iqr = upper_quartile - lower_quartile
    
    # Calculate lower and upper bounds to identify potential outliers
    lower_bound = lower_quartile - (1.5 * iqr)
    upper_bound = upper_quartile + (1.5 * iqr)
    
    # Locate and identify potential outliers
    outliers = regimen_data[(regimen_data < lower_bound) | (regimen_data > upper_bound)]
    
    # Print the results for the current regimen
    print(f"{regimen}'s potential outliers: {outliers if not outliers.empty else 'No outliers'}")
# Out:
# Capomulin's potential outliers: No outliers
# Ramicane's potential outliers: No outliers
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: No outliers

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
# Create a list of tumor volume data for each treatment regimen
tumor_volume_data = [merged_data[merged_data["Drug Regimen"] == regimen]["Tumor Volume (mm3)"] for regimen in target_regimens]

# Create a box plot
plt.boxplot(tumor_volume_data, labels=target_regimens, flierprops={"markerfacecolor": "red", "markersize": 8})
plt.title("Tumor Volume Distribution by Treatment Regimen")
plt.xlabel("Treatment Regimen")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(axis="y")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
# Choose a specific mouse ID treated with Capomulin (replace 'your_mouse_id' with the actual mouse ID)
mouse_id_capomulin = 'l509'

# Filter the data for the chosen mouse ID and Capomulin regimen
mouse_data_capomulin = cleaned_data_no_duplicates[(cleaned_data_no_duplicates["Drug Regimen"] == "Capomulin") & (cleaned_data_no_duplicates["Mouse ID"] == mouse_id_capomulin)]

# Create a line plot for tumor volume vs. time point
plt.plot(mouse_data_capomulin["Timepoint"], mouse_data_capomulin["Tumor Volume (mm3)"], marker='o', linestyle='-')
plt.title(f"Tumor Volume vs. Time Point for Mouse {mouse_id_capomulin} (Capomulin)")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
# Filter the data for the Capomulin regimen
capomulin_data = cleaned_data_no_duplicates[cleaned_data_no_duplicates["Drug Regimen"] == "Capomulin"]

# Group the data by Mouse ID and calculate the average tumor volume for each mouse
average_tumor_volume = capomulin_data.groupby("Mouse ID")["Tumor Volume (mm3)"].mean()
mouse_weight = capomulin_data.groupby("Mouse ID")["Weight (g)"].mean()

# Create a scatter plot for mouse weight vs. average tumor volume
plt.scatter(mouse_weight, average_tumor_volume, marker='o', facecolors='blue', edgecolors='black')
plt.title("Mouse Weight vs. Average Tumor Volume (Capomulin)")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
from scipy.stats import pearsonr, linregress

# Filter the data for the Capomulin regimen
capomulin_data = cleaned_data_no_duplicates[cleaned_data_no_duplicates["Drug Regimen"] == "Capomulin"]

# Group the data by Mouse ID and calculate the average tumor volume and mouse weight for each mouse
average_tumor_volume = capomulin_data.groupby("Mouse ID")["Tumor Volume (mm3)"].mean()
mouse_weight = capomulin_data.groupby("Mouse ID")["Weight (g)"].mean()

# Calculate the correlation coefficient between mouse weight and average tumor volume
correlation_coefficient, _ = pearsonr(mouse_weight, average_tumor_volume)

# Perform linear regression to get the slope, intercept, r-value, p-value, and standard error
slope, intercept, r_value, p_value, std_err = linregress(mouse_weight, average_tumor_volume)

# Create a linear regression equation string
regression_equation = f"y = {slope:.2f}x + {intercept:.2f}"

# Create a scatter plot for mouse weight vs. average tumor volume
plt.scatter(mouse_weight, average_tumor_volume, marker='o', facecolors='blue', edgecolors='black')
plt.title("Mouse Weight vs. Average Tumor Volume (Capomulin)")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.grid(True)

# Add the linear regression line to the plot
plt.plot(mouse_weight, slope * mouse_weight + intercept, color='red', linestyle='--', label=regression_equation)

# Add legend
plt.legend()

# Show the plot
plt.show()

# Print the correlation coefficient and linear regression results
print(f"Correlation Coefficient: {correlation_coefficient:.2f}")
print(f"Linear Regression Results:")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared Value: {r_value**2:.2f}")
print(f"P-value: {p_value:.2f}")
print(f"Standard Error: {std_err:.2f}")
# Out:
# Correlation Coefficient: 0.84
# Linear Regression Results:
# Slope: 0.95
# Intercept: 21.55
# R-squared Value: 0.71
# P-value: 0.00
# Standard Error: 0.13
